# %% [markdown]
# # Matplotlib
# **Matplotlib**, as the name suggests is a plotting library that is used in fields like data analytics. Matplotlib is widely used as it is compatible with other libraries like opencv and pandas.

# %% [markdown]
# # Basics of Matplotlib:
# - `plot()` &#8594; Creates a line chart.
# - `scatter()` &#8594; Creates a scatter chart.
# - `bar()` &#8594; Creates a bar chart.
# - `barh()` &#8594; Creates a horizontal bar chart.
# - `hist()` &#8594; Creates a histogram.
# - `pie()` &#8594; Creates a pie chart.
#
# We'll use numpy to generate random data for the charts, if need be we'll use pandas to read a csv file and use that for charts.

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.arange(10,100)
Y = np.arange(10,100)
plt.plot(X,Y,color = '#1A507B',label="Random line") #Creates the plot
plt.title("Random Line chart")#Adds title to the created plot
plt.xlabel("X Axis")# Adds label to X-Axis in the plot 
plt.ylabel("Y Axis")# Adds label to Y-Axis in the plot
plt.legend() #Includes the label in the plot.
plt.show()#Displays the plot

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, c='blue', alpha=0.5, label='Random Data')#Creates the scatter plot, alpha controls the transparency of each point in the Plot. C controls the color  
plt.title('Random Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %% [markdown]
# <b>Combining two plots</b>
#
# - Combining scatter and line plots is very important is evaluation of models. In regression use cases like `Linearregression`, there may be points for the overall data spread and a line indicating the model's output.

# %%
x = np.linspace(0,10,30)
y = np.cos(x)

#create the scatter plot
plt.scatter(x, y, color='blue', label='Data Points')
#create the line plot
plt.plot(x, y, color='red', label='Trend Line')

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend()
plt.show()

# %% [markdown]
# ---
# Bar Graph

# %%
import pandas as pd
df = pd.read_csv("""Salary Data.csv""") #Same data used in pandas

# %%
df.dropna(inplace=True)

# %%
plt.bar(df["Education Level"],df['Salary'].astype(int),label="Salary",width=0.6)
plt.xlabel("Education")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %% [markdown]
# ---
# Barh graph
# - The barh graph is very similar to the bar graph, it simply, rotates the bar graph horizontally. It tkaes the params of data and the width, the width determines the max ACTUAL data of the bar.

# %%
education_level = list(df['Education Level'])
salary = list(df['Salary'].astype(int))
plt.barh(education_level,salary,color="skyblue",label="Salary",)
plt.xlabel("Education")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %% [markdown]
# **Histogram**
# - Histograms are a powerful type of chart that can be used to display the frequency disribution of data. Histograms are mostly used in population related data analytics. These plots are helpful with displaying the *normal distrubition of data*.
#
# *Normal Distrubution of data:* Normal distribution of data is the most common/normal form of distrubution of random variables. It serves as a foundation for statistics and probability theory.

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30, color='skyblue', edgecolor='black',label="Random Data") #bins distributes the data in specified number of equal widths.
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')
plt.legend()
plt.show()

# %% [markdown]
# **Seaborn:**
# - Seaborn is also a plotting library used in tandem with matplotlib for creating various plots that matplotlib doesn't support well(like KDE plots and confusion matrices.)

# %%
import seaborn as sns
sns.histplot(data,bins=30,kde=True,color="lightgreen",edgecolor="red")#kde = True, displays the line on top of the histogram, we can use sns.kdeplot to plot JUST the line.
plt.show()

# %%
sns.kdeplot(data,color='lightgreen')
plt.show()

# %% [markdown]
# **Pie Charts:**
# - Pie charts can be used to show parts-to-whole relationships and to demonstrate each element's contribution to the whole.

# %%
pie_data = df['Education Level'].value_counts()
plt.pie(x=pie_data,labels=["Bachleor's","Master's","PhD"],shadow=True,colors=["#5c7bd9","#ffdc60","#9fe080"],explode=[0.1,0,0])
plt.title("Distrubution of Education")
plt.legend()
plt.show()

# %% [markdown]
# - labels: is the actual label of the data, should be passed in the same order as the data.
# - shadow: boolean value, makes the pie a bit more attractive and better to look at.
# - explode: used to emphasize a certain value/data in the input, the higher the value, the further it goes away.

# %% [markdown]
# **Heatmaps:**
# - Heatmaps are strong data visualization technique which represents values in a matrix and is color coded(higher value &#8594; higher color intensity)

# %%
np.random.seed(5)
data = np.random.rand(5,5)
sns.heatmap(data,annot=True,cmap="YlGnBu",)
plt.title("Random Data Heatmap")
plt.show()

# %% [markdown]
# annot: determines if the values for each element should be written or not.If set to false, the output would be like so:
#
# ![image.png](attachment:image.png)
#
#
# cmap: colormap, the color palette to be used.

# %% [markdown]
# ---
# **Plotly:**
# - Plotly, similar to seaborn is another data visualization tool that can help us create more interactive plots and charts rather than just the plots. These charts are more visually appealing and also more engaging.

# %%
import plotly.graph_objects as go

years = [2018,2019,2020,2021]
sales = [100,200,250,300]
fig = go.Figure(data = go.Scatter(x=years,y=sales))
fig.show()

# %%
fig.update_layout(
    title = "Sales over year",
    xaxis_title="Year",
    yaxis_title="Sales"
)
fig.show()

# %%
def find_highest_sales(sales:list|tuple,years:list|tuple)->tuple:
    max_sales = max(sales)
    max_idx = sales.index(max_sales)   
    return years[max_idx], max_sales

# %%
year,sale = find_highest_sales(sales=sales,years=years)
fig.add_annotation(
    x=year,
    y=sale,
    text="Highest Sales"
)
fig.show()
