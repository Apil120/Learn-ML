# %% [markdown]
# # Machine Learning :
# - Machine Learning or ML for short is a field of Artificial Inteligence that focuses on enabling computers to learn from data and patterns and improve their performance on specific tasks without being explicitly programmed.
#
# # Types of Machine Learning:

# %% [markdown]
# Machine Learning can be widely classified in three tyoes:
# - Supervised Learning:
#     - Supervised Learning is a type of ML where the ML model learns from labeled data. Generally algorithms like Decision Trees fall under this category.
#
# - Unsupervised Learning:
#     - Unsupervised Learning is a type of ML where the model figures out patterns in data. Algorithms like K-Means fall under this category.
#
# - Reinforcement Learning:
#     - Reinforcement Learning is a type of ML where the model learns by interacting with an environment to achieve a goal. The model is rewarded or punishment based on the decision it takes.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Components of ML:
